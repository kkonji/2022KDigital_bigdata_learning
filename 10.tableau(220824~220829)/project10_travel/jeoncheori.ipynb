# %%
import pandas as pd
df = pd.read_excel('./DATA/향후제주여행계획조사.xlsx')
df
# Out:
#           항목  기준                         경우  \
# 0   제주여행선택이유  전체             해외여행 대체지로 적절해서
# 1   제주여행선택이유  전체                   청정한 자연환경
# 2   제주여행선택이유  전체  **적당한 이동 거리 (물리적, 시간적 거리)
# 3   제주여행선택이유  전체           관광 편의성(숙박, 교통 등)
# 4   제주여행선택이유  전체                  관광활동의 다양성
# 5   제주여행선택이유  전체        전염병 안전지역 (코로나 19 등)
# 6   제주여행선택이유  전체                       여행비용
# 7   제주여행선택이유  전체                         기타
# 8     제주여행활동  전체                     자연경관감상
# 9     제주여행활동  전체                  식도락(맛집여행)
# 10    제주여행활동  전체               산/오름/올레길 트레킹
# 11    제주여행활동  전체         호캉스(호텔, 펜션, 리조트 등)
# 12    제주여행활동  전체                박물관/테마공원 방문
# 13    제주여행활동  전체                 역사/문화유적지방문
# 14    제주여행활동  전체      레포츠 활동(골프, 승마, ATV 등)
# 15    제주여행활동  전체                   지인/친지 방문
# 16    제주여행활동  전체               공연/축제/이벤트 참여
# 17    제주여행활동  전체              영화/드라마 촬영지 방문
# 18    제주여행활동  전체                   유흥/오락/경마
# 19    제주여행활동  전체                         기타
#
# ...

# %%
df[['전체', '남', '여', '10대', '20대', '30대', '40대', '50대', '60대', '70대이상']] = df['비율'].str.split(expand=True)

# %%
df = df.drop('비율', axis=1)

# %%
df.to_csv('향후제주여행계획.csv')
