# %% [markdown]
# # 그래프 관련 분석

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
import platform
# 한글 폰트 설정
if	platform.system()	==	'Windows':
    plt.rc('font',	family='Malgun Gothic')
else:
    plt.rc('font',	family='AppleGothic')
dic = {0: 'tab:blue', 1:'tab:orange', 2:'tab:green', 3:'tab:red', 4:'tab:purple', 5:'tab:brown', 6:'tab:pink', 7:'tab:gray', 8:'tab:olive', 9:'tab:cyan'}
plt.ylim([8,10])
plt.bar([0,1],[9.3,9.5], color=dic[2], width=0.6)
plt.xticks([0,1], ["2017년", "2020년"])
plt.yticks([8.50,9.00,9.50,10.00], ["8.5", "9", "9.5", "10"])
plt.text(-0.07,9.4,"9.3", fontsize=20)
plt.text(0.93,9.6,"9.5", fontsize=20)

plt.show()
